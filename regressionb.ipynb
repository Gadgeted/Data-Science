# %%
# Regression
import pandas
data = pandas.read_csv('datasets/advertising.csv')
data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
array = data.values
x = array[:, 1:3] #TV, Radio, Newspaper
y = array[:, 4] #Sales
x
# Out:
# array([[230.1,  37.8],
#        [ 44.5,  39.3],
#        [ 17.2,  45.9],
#        [151.5,  41.3],
#        [180.8,  10.8],
#        [  8.7,  48.9],
#        [ 57.5,  32.8],
#        [120.2,  19.6],
#        [  8.6,   2.1],
#        [199.8,   2.6],
#        [ 66.1,   5.8],
#        [214.7,  24. ],
#        [ 23.8,  35.1],
#        [ 97.5,   7.6],
#        [204.1,  32.9],
#        [195.4,  47.7],
#        [ 67.8,  36.6],
#        [281.4,  39.6],
#        [ 69.2,  20.5],
#        [147.3,  23.9],
#        [218.4,  27.7],
#        [237.4,   5.1],
#        [ 13.2,  15.9],
#        [228.3,  16.9],
#        [ 62.3,  12.6],
#        [262.9,   3.5],
#        [142.9,  29.3],
#        [240.1,  16.7],
#        [248.8,  27.1],
#        [ 70.6,  16. ],
#        [292.9,  28.3],
#        [112.9,  17.4],
#        [ 97.2,   1.5],
#        [265.6,  20. ],
#        [ 95.7,   1.4],
#        [290.7,   4.1],
#        [266.9,  43.8],
#        [ 74.7,  49.4],
#        [ 43.1,  26.7],
#        [228. ,  37.7],
# ...

# %%
from sklearn import model_selection
x_train, x_test, y_train, y_test = model_selection.train_test_split(x,y, test_size = 0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(x_test)
print("Prediction: ", prediction)
print("Expected: ", y_test)
# Out:
# Prediction:  [16.43778963 21.11462413 21.48161733 10.82947123 22.47553785 13.23902536
#  21.28797822  7.39171109 13.32928225 15.11419102  9.21015343  6.46961736
#  13.86261835  9.13354422  9.41188141 11.91990874  8.85260103 16.26801624
#  10.26953764 18.8732391  19.49753509 13.24142966 12.67756515 21.29173445
#   7.76318799  5.60096753 20.96017782 11.91537611  9.07191016  8.71874103
#  12.17104929 10.04118685 21.61332453 12.43639201 18.02635199 20.28621948
#  14.48901992 20.75689534 10.9817875   4.3739138   9.51065505 12.52354331
#  10.14692274  8.13646833 13.19720037  5.27101348  9.19116969 14.17248822
#   8.60296178 11.77237575 15.76641197 11.69874553 13.12850705 11.06278083
#   6.36721238  9.6960804   9.51719197 24.177049    7.77390733 12.25642418]
# Expected:  [16.9 22.4 21.4  7.3 24.7 12.6 22.3  8.4 11.5 14.9  9.5  8.7 11.9  5.3
#  10.3 11.7  5.5 16.6 11.3 18.9 19.7 12.5 10.9 22.2  9.3  8.1 21.7 13.4
#  10.6  5.7 10.6 11.3 23.7  8.7 16.1 20.7 11.6 20.8 11.9  6.9 11.  12.8
# ...

# %%
from sklearn.metrics import r2_score
print("Accuracy ", r2_score(prediction, y_test))
# Out:
# Accuracy  0.8506195361912849

# %%
expense = [[200, 2000]]
outcome = model.predict(expense)
print("You will sell ", outcome, 'Units')
# Out:
# You will sell  [416.86440899] Units

# %%
expense=[[2, 20000,]] #tv radio newspper
outcome = model.predict(expense)
print("Nyambu's sell is", outcome, 'Units')
# Out:
# Nyambu's sell is [4055.03896139] Units
